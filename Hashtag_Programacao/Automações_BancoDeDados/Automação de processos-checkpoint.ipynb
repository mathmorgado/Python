# %%
import pyautogui as pa
import pyperclip as pc
import pandas as pd
import time

pa.PAUSE = 0.75

time.sleep(10)

pa.press("win")
pa.write("chrome")
pa.press("enter")

time.sleep(1)

pa.click(x=794, y=586) #selecionar usuario

time.sleep(3)

pa.hotkey('ctrl', 't') # abrir nova aba
pc.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga") # link do site
pa.hotkey('ctrl', 'v')
pa.press('enter')

time.sleep(3)

pa.click(x=400, y=288, clicks=2) # area de exportação

time.sleep(2)

pa.click(x=400, y=288) # arquivo
pa.click(x=1730, y=194) # tres pontinho
pa.click(x=1552, y=546) # download

time.sleep(3)

tabela = pd.read_excel(r'C:\Users\mathe\Downloads\Vendas - Dez.xlsx')
faturamento = tabela['Valor Final'].sum()
qtde_prod = tabela['Quantidade'].sum()



pa.press("win")
pa.write("email")
pa.press("enter")
time.sleep(3)
pa.click(x=118, y=106)
pa.write('matheusrmorgado@hotmail.com')
pa.press('tab')
pa.press('tab')
pa.press('tab')
pc.copy('Relatório de Vendas')
pa.hotkey('ctrl', 'v')
pa.press('tab')
texto = f"""
Prezados, bom dia!

O faturamento do mês de dezembro foi: R$ {faturamento:,.2f}
A quantidade de produtos vendidos foi: R$ {qtde_prod:,}

abs
Matheus Morgado
"""
pc.copy(texto)
pa.hotkey('ctrl', 'v')
pa.hotkey('ctrl', 'enter')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22220\2364074432.py in <module>
#      35 time.sleep(3)
#      36
# ---> 37 tabela = pd.read_excel(r'C:\Users\mathe\Downloads\Vendas - Dez.xlsx')
#      38 faturamento = tabela['Valor Final'].sum()
#      39 qtde_prod = tabela['Quantidade'].sum()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import time

time.sleep(5)
pa.position()

# %%
pa.press("win")
pa.write("email")
pa.press("enter")
time.sleep(5)
pa.click(x=118, y=106)
pa.write('matheusrmorgado@hotmail.com')
pa.press('tab')
pa.press('tab')
pa.press('tab')
pc.copy('Relatório de Vendas')
pa.hotkey('ctrl', 'v')
pa.press('tab')
texto = f"""
Prezados, bom dia!

O faturamento do mês de dezembro foi: R$ {faturamento:,.2f}
A quantidade de produtos vendidos foi: R$ {qtde_prod:,}

abs
Matheus Morgado
"""
pc.copy(texto)
pa.hotkey('ctrl', 'v')
pa.hotkey('ctrl', 'enter')

# %%
import pandas as pd
tabela = pd.read_excel(r'C:\Users\mathe\Downloads\Vendas - Dez.xlsx')
display(tabela)
faturamento = tabela['Valor Final'].sum()
qtde_prod = tabela['Quantidade'].sum()


display(faturamento)
display(qtde_prod)
# Out:
#       Código Venda       Data  ... Valor Unitário Valor Final
# 0            65014 2019-12-01  ...            114         570
# 1            65014 2019-12-01  ...            269         269
# 2            65016 2019-12-01  ...            363         726
# 3            65016 2019-12-01  ...            250         250
# 4            65017 2019-12-01  ...             92         276
# ...            ...        ...  ...            ...         ...
# 7084         69996 2019-12-26  ...            102         204
# 7085         69996 2019-12-26  ...            270        1080
# 7086         69996 2019-12-26  ...             87          87
# 7087         69997 2019-12-26  ...            108         108
# 7088         69997 2019-12-26  ...            133         266
#
# [7089 rows x 7 columns]
# 2917311
# 15227

# %%
import pyautogui as pa
import pyperclip as pc
import pandas as pd
import time

pa.PAUSE = 0.75

time.sleep(10)

pa.press("win")
pa.write("chrome")
pa.press("enter")
time.sleep(1)
pa.click(x=794, y=586) #selecionar usuario

time.sleep(3)

pa.hotkey('ctrl', 't') # abrir nova aba
pc.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga") # link do site
pa.hotkey('ctrl', 'v')
pa.press('enter')

# %%
import pandas as pd
tabela = pd.read_excel(r'C:\Users\mathe\Downloads\Vendas - Dez.xlsx')
display(tabela)
faturamento = tabela['Valor Final'].sum()
qtde_prod = tabela['Quantidade'].sum()


display(faturamento)
display(qtde_prod)
